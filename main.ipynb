# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(
    '/content/drive/MyDrive/Fraud Detection/CC.csv'
)

# %%
df.head()
# Out:
#    Unnamed: 0  Time        V1        V2        V3        V4        V5  \
# 0           1   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321
# 1           2   0.0  1.191857  0.266151  0.166480  0.448154  0.060018
# 2           3   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198
# 3           4   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309
# 4           5   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193
#
#          V6        V7        V8  ...       V21       V22       V23       V24  \
# 0  0.462388  0.239599  0.098698  ... -0.018307  0.277838 -0.110474  0.066928
# 1 -0.082361 -0.078803  0.085102  ... -0.225775 -0.638672  0.101288 -0.339846
# 2  1.800499  0.791461  0.247676  ...  0.247998  0.771679  0.909412 -0.689281
# 3  1.247203  0.237609  0.377436  ... -0.108300  0.005274 -0.190321 -1.175575
# 4  0.095921  0.592941 -0.270533  ... -0.009431  0.798278 -0.137458  0.141267
#
#         V25       V26       V27       V28  Amount  Class
# ...

# %%
df
# Out:
#         Unnamed: 0      Time         V1         V2        V3        V4  \
# 0                1       0.0  -1.359807  -0.072781  2.536347  1.378155
# 1                2       0.0   1.191857   0.266151  0.166480  0.448154
# 2                3       1.0  -1.358354  -1.340163  1.773209  0.379780
# 3                4       1.0  -0.966272  -0.185226  1.792993 -0.863291
# 4                5       2.0  -1.158233   0.877737  1.548718  0.403034
# ...            ...       ...        ...        ...       ...       ...
# 284802      284803  172786.0 -11.881118  10.071785 -9.834783 -2.066656
# 284803      284804  172787.0  -0.732789  -0.055080  2.035030 -0.738589
# 284804      284805  172788.0   1.919565  -0.301254 -3.249640 -0.557828
# 284805      284806  172788.0  -0.240440   0.530483  0.702510  0.689799
# 284806      284807  172792.0  -0.533413  -0.189733  0.703337 -0.506271
#
#               V5        V6        V7        V8  ...       V21       V22  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 32 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Unnamed: 0  284807 non-null  int64
#  1   Time        284807 non-null  float64
#  2   V1          284807 non-null  float64
#  3   V2          284807 non-null  float64
#  4   V3          284807 non-null  float64
#  5   V4          284807 non-null  float64
#  6   V5          284807 non-null  float64
#  7   V6          284807 non-null  float64
#  8   V7          284807 non-null  float64
#  9   V8          284807 non-null  float64
#  10  V9          284807 non-null  float64
#  11  V10         284807 non-null  float64
#  12  V11         284807 non-null  float64
#  13  V12         284807 non-null  float64
#  14  V13         284807 non-null  float64
#  15  V14         284807 non-null  float64
#  16  V15         284807 non-null  float64
#  17  V16         284807 non-null  float64
# ...

# %%
df.drop(['Unnamed: 0'], inplace = True, axis = 1)

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
df.drop(['Time'], axis = 1).hist(bins=50,figsize=(20,15))
# Out:
# array([[<Axes: title={'center': 'V1'}>, <Axes: title={'center': 'V2'}>,
#         <Axes: title={'center': 'V3'}>, <Axes: title={'center': 'V4'}>,
#         <Axes: title={'center': 'V5'}>],
#        [<Axes: title={'center': 'V6'}>, <Axes: title={'center': 'V7'}>,
#         <Axes: title={'center': 'V8'}>, <Axes: title={'center': 'V9'}>,
#         <Axes: title={'center': 'V10'}>],
#        [<Axes: title={'center': 'V11'}>, <Axes: title={'center': 'V12'}>,
#         <Axes: title={'center': 'V13'}>, <Axes: title={'center': 'V14'}>,
#         <Axes: title={'center': 'V15'}>],
#        [<Axes: title={'center': 'V16'}>, <Axes: title={'center': 'V17'}>,
#         <Axes: title={'center': 'V18'}>, <Axes: title={'center': 'V19'}>,
#         <Axes: title={'center': 'V20'}>],
#        [<Axes: title={'center': 'V21'}>, <Axes: title={'center': 'V22'}>,
#         <Axes: title={'center': 'V23'}>, <Axes: title={'center': 'V24'}>,
#         <Axes: title={'center': 'V25'}>],
# ...

# %%
df['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
df.drop(['Time'], axis = 1,inplace = True)

# %%
df.boxplot(figsize=(20,15))
# Out:
# <Axes: >

# %%
import seaborn as sns

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
df.duplicated().any()
# Out:
# True

# %%
df.drop_duplicates(inplace=True)

# %%
df['Class'].value_counts()
# Out:
# 0    275190
# 1       473
# Name: Class, dtype: int64

# %%
X = df.drop(['Class'],axis = 1)
y = df['Class']
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=78,stratify=y)

# %%
sc = StandardScaler()
X_train['Amount'] = sc.fit_transform(pd.DataFrame(X_train['Amount']))
X_test['Amount'] = sc.transform(pd.DataFrame(X_test['Amount']))

# %%
X_train.boxplot(figsize=(20,15))
# Out:
# <Axes: >

# %%
plt.figure(figsize = (8,8))
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
df.corr()['Class'][:-1].abs().sort_values().plot(kind='bar', title='Most important features')
# Out:
# <Axes: title={'center': 'Most important features'}>

# %%
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, roc_auc_score,recall_score,precision_score,f1_score,accuracy_score

# %%
scores = []

# %%
model = RandomForestClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
scores.append({
      'model':'RandomForest',
      'accuracy': accuracy_score(y_test,y_pred),
      'recall': recall_score(y_test,y_pred),
      'precision':precision_score(y_test,y_pred),
      'f1_score':f1_score(y_test,y_pred),
      'roc_auc_score':roc_auc_score(y_test,y_pred)
      })

# %%
model = LogisticRegression()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
scores.append({
      'model':'LogisticRegression',
      'accuracy': accuracy_score(y_test,y_pred),
      'recall': recall_score(y_test,y_pred),
      'precision':precision_score(y_test,y_pred),
      'f1_score':f1_score(y_test,y_pred),
      'roc_auc_score':roc_auc_score(y_test,y_pred)
      })

# %%
model = DecisionTreeClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
scores.append({
      'model':'DecisionTreeClassifier',
      'accuracy': accuracy_score(y_test,y_pred),
      'recall': recall_score(y_test,y_pred),
      'precision':precision_score(y_test,y_pred),
      'f1_score':f1_score(y_test,y_pred),
      'roc_auc_score':roc_auc_score(y_test,y_pred)
      })

# %%
model = GradientBoostingClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
scores.append({
      'model':'GradientBoostingClassifier',
      'accuracy': accuracy_score(y_test,y_pred),
      'recall': recall_score(y_test,y_pred),
      'precision':precision_score(y_test,y_pred),
      'f1_score':f1_score(y_test,y_pred),
      'roc_auc_score':roc_auc_score(y_test,y_pred)
      })

# %%
scores
# Out:
# [{'model': 'RandomForest',
#   'accuracy': 0.9995646874455859,
#   'recall': 0.788135593220339,
#   'precision': 0.9489795918367347,
#   'f1_score': 0.861111111111111,
#   'roc_auc_score': 0.8940314583445224},
#  {'model': 'LogisticRegression',
#   'accuracy': 0.9991583957281328,
#   'recall': 0.576271186440678,
#   'precision': 0.8947368421052632,
#   'f1_score': 0.7010309278350517,
#   'roc_auc_score': 0.7880774519953033},
#  {'model': 'DecisionTreeClassifier',
#   'accuracy': 0.9991729061466132,
#   'recall': 0.7796610169491526,
#   'precision': 0.7479674796747967,
#   'f1_score': 0.7634854771784233,
#   'roc_auc_score': 0.8896052112275633},
#  {'model': 'GradientBoostingClassifier',
#   'accuracy': 0.9993034999129375,
#   'recall': 0.6694915254237288,
#   'precision': 0.8977272727272727,
#   'f1_score': 0.7669902912621359,
#   'roc_auc_score': 0.8346803538336993}]

# %%
k = pd.DataFrame(scores,columns=['model','accuracy','recall','precision','f1_score','roc_auc_score'])
k
# Out:
#                         model  accuracy    recall  precision  f1_score  \
# 0                RandomForest  0.999565  0.788136   0.948980  0.861111
# 1          LogisticRegression  0.999158  0.576271   0.894737  0.701031
# 2      DecisionTreeClassifier  0.999173  0.779661   0.747967  0.763485
# 3  GradientBoostingClassifier  0.999303  0.669492   0.897727  0.766990
#
#    roc_auc_score
# 0       0.894031
# 1       0.788077
# 2       0.889605
# 3       0.834680

# %%
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import TomekLinks

# %%
tl = TomekLinks()
X_train_u,y_train_u = tl.fit_resample(X_train,y_train)

# %%
scores_u = []

# %%
model = RandomForestClassifier()
model.fit(X_train_u,y_train_u)
y_pred = model.predict(X_test)
scores_u.append({
      'model':'RandomForest+Tomek',
      'accuracy': accuracy_score(y_test,y_pred),
      'recall': recall_score(y_test,y_pred),
      'precision':precision_score(y_test,y_pred),
      'f1_score':f1_score(y_test,y_pred),
      'roc_auc_score':roc_auc_score(y_test,y_pred)
      })

# %%
model = LogisticRegression()
model.fit(X_train_u,y_train_u)
y_pred = model.predict(X_test)
scores_u.append({
      'model':'LogisticRegression+Tomek',
      'accuracy': accuracy_score(y_test,y_pred),
      'recall': recall_score(y_test,y_pred),
      'precision':precision_score(y_test,y_pred),
      'f1_score':f1_score(y_test,y_pred),
      'roc_auc_score':roc_auc_score(y_test,y_pred)
      })

# %%
model = DecisionTreeClassifier()
model.fit(X_train_u,y_train_u)
y_pred = model.predict(X_test)
scores_u.append({
      'model':'DecisionTreeClassifier+Tomek',
      'accuracy': accuracy_score(y_test,y_pred),
      'recall': recall_score(y_test,y_pred),
      'precision':precision_score(y_test,y_pred),
      'f1_score':f1_score(y_test,y_pred),
      'roc_auc_score':roc_auc_score(y_test,y_pred)
      })

# %%
model = GradientBoostingClassifier()
model.fit(X_train_u,y_train_u)
y_pred = model.predict(X_test)
scores_u.append({
      'model':'GradientBoostingClassifier+Tomek',
      'accuracy': accuracy_score(y_test,y_pred),
      'recall': recall_score(y_test,y_pred),
      'precision':precision_score(y_test,y_pred),
      'f1_score':f1_score(y_test,y_pred),
      'roc_auc_score':roc_auc_score(y_test,y_pred)
      })

# %%
u = pd.DataFrame(scores_u,columns=['model','accuracy','recall','precision','f1_score','roc_auc_score'])
u
# Out:
#                               model  accuracy    recall  precision  f1_score  \
# 0                RandomForest+Tomek  0.999594  0.805085   0.950000  0.871560
# 1          LogisticRegression+Tomek  0.999173  0.584746   0.896104  0.707692
# 2      DecisionTreeClassifier+Tomek  0.999158  0.771186   0.745902  0.758333
# 3  GradientBoostingClassifier+Tomek  0.999333  0.779661   0.821429  0.800000
#
#    roc_auc_score
# 0       0.902506
# 1       0.792315
# 2       0.885368
# 3       0.889685

# %%
smt = SMOTE()
X_train_o,y_train_o = smt.fit_resample(X_train,y_train)

# %%
scores_o = []

# %%
model = RandomForestClassifier()
model.fit(X_train_o,y_train_o)
y_pred = model.predict(X_test)
scores_o.append({
      'model':'RandomForest+SMOTE',
      'accuracy': accuracy_score(y_test,y_pred),
      'recall': recall_score(y_test,y_pred),
      'precision':precision_score(y_test,y_pred),
      'f1_score':f1_score(y_test,y_pred),
      'roc_auc_score':roc_auc_score(y_test,y_pred)
      })

# %%
model = LogisticRegression()
model.fit(X_train_o,y_train_o)
y_pred = model.predict(X_test)
scores_o.append({
      'model':'LogisticRegression+SMOTE',
      'accuracy': accuracy_score(y_test,y_pred),
      'recall': recall_score(y_test,y_pred),
      'precision':precision_score(y_test,y_pred),
      'f1_score':f1_score(y_test,y_pred),
      'roc_auc_score':roc_auc_score(y_test,y_pred)
      })

# %%
model = DecisionTreeClassifier()
model.fit(X_train_o,y_train_o)
y_pred = model.predict(X_test)
scores_o.append({
      'model':'DecisionTreeClassifier+SMOTE',
      'accuracy': accuracy_score(y_test,y_pred),
      'recall': recall_score(y_test,y_pred),
      'precision':precision_score(y_test,y_pred),
      'f1_score':f1_score(y_test,y_pred),
      'roc_auc_score':roc_auc_score(y_test,y_pred)
      })

# %%
model = GradientBoostingClassifier()
model.fit(X_train_o,y_train_o)
y_pred = model.predict(X_test)
scores_o.append({
      'model':'GradientBoostingClassifier+SMOTE',
      'accuracy': accuracy_score(y_test,y_pred),
      'recall': recall_score(y_test,y_pred),
      'precision':precision_score(y_test,y_pred),
      'f1_score':f1_score(y_test,y_pred),
      'roc_auc_score':roc_auc_score(y_test,y_pred)
      })

# %%
o = pd.DataFrame(scores_o,columns=['model','accuracy','recall','precision','f1_score','roc_auc_score'])
o
# Out:
#                               model  accuracy    recall  precision  f1_score  \
# 0                RandomForest+SMOTE  0.999463  0.796610   0.878505  0.835556
# 1          LogisticRegression+SMOTE  0.973315  0.932203   0.056672  0.106848
# 2      DecisionTreeClassifier+SMOTE  0.997141  0.771186   0.348659  0.480211
# 3  GradientBoostingClassifier+SMOTE  0.987347  0.915254   0.111340  0.198529
#
#    roc_auc_score
# 0       0.898211
# 1       0.952795
# 2       0.884358
# 3       0.951362

# %%
from imblearn.combine import SMOTETomek

# %%
scores_b = []

# %%
sto = SMOTETomek()
X_train_b,y_train_b = sto.fit_resample(X_train,y_train)

# %%
model = RandomForestClassifier()
model.fit(X_train_b,y_train_b)
y_pred = model.predict(X_test)
scores_b.append({
      'model':'RandomForest+SMOTE+Tomek',
      'accuracy': accuracy_score(y_test,y_pred),
      'recall': recall_score(y_test,y_pred),
      'precision':precision_score(y_test,y_pred),
      'f1_score':f1_score(y_test,y_pred),
      'roc_auc_score':roc_auc_score(y_test,y_pred)
      })

# %%
model = LogisticRegression()
model.fit(X_train_b,y_train_b)
y_pred = model.predict(X_test)
scores_b.append({
      'model':'LogisticRegression+SMOTE+Tomek',
      'accuracy': accuracy_score(y_test,y_pred),
      'recall': recall_score(y_test,y_pred),
      'precision':precision_score(y_test,y_pred),
      'f1_score':f1_score(y_test,y_pred),
      'roc_auc_score':roc_auc_score(y_test,y_pred)
      })

# %%
model = DecisionTreeClassifier()
model.fit(X_train_b,y_train_b)
y_pred = model.predict(X_test)
scores_b.append({
      'model':'DecisionTreeClassifier+SMOTE+Tomek',
      'accuracy': accuracy_score(y_test,y_pred),
      'recall': recall_score(y_test,y_pred),
      'precision':precision_score(y_test,y_pred),
      'f1_score':f1_score(y_test,y_pred),
      'roc_auc_score':roc_auc_score(y_test,y_pred)
      })

# %%
model = GradientBoostingClassifier()
model.fit(X_train_b,y_train_b)
y_pred = model.predict(X_test)
scores_b.append({
      'model':'GradientBoostingClassifier+SMOTE+Tomek',
      'accuracy': accuracy_score(y_test,y_pred),
      'recall': recall_score(y_test,y_pred),
      'precision':precision_score(y_test,y_pred),
      'f1_score':f1_score(y_test,y_pred),
      'roc_auc_score':roc_auc_score(y_test,y_pred)
      })

# %%
b = pd.DataFrame(scores_b,columns=['model','accuracy','recall','precision','f1_score','roc_auc_score'])
b
# Out:
#                                     model  accuracy    recall  precision  \
# 0                RandomForest+SMOTE+Tomek  0.999478  0.805085   0.879630
# 1          LogisticRegression+SMOTE+Tomek  0.973431  0.932203   0.056906
# 2      DecisionTreeClassifier+SMOTE+Tomek  0.997141  0.771186   0.348659
# 3  GradientBoostingClassifier+SMOTE+Tomek  0.986897  0.906780   0.107107
#
#    f1_score  roc_auc_score
# 0  0.840708       0.902448
# 1  0.107265       0.952853
# 2  0.480211       0.884358
# 3  0.191585       0.946907

# %%
model = RandomForestClassifier()
model.fit(X_train_b,y_train_b)
# Out:
# RandomForestClassifier()

# %%
final_model = model
best_combination = 'RandomForest+SMOTE+Tomek'

# %%
results = b.head(1)
results
# Out:
#                       model  accuracy    recall  precision  f1_score  \
# 0  RandomForest+SMOTE+Tomek  0.999478  0.805085    0.87963  0.840708
#
#    roc_auc_score
# 0       0.902448
